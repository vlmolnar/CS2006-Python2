# %%
import pandas as pd

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import refine as rf

# %%
import analysis as an

# %%
import visualisation as vis

# %%
df=pd.read_csv("../data/CometLanding_ref.csv")

# %%
# df.dtypes

# %%
vis.plotStructure(df)

# %%
vis.plotApps(df)

# %%
# an.getMostPopularHashtags(df, 10)

# %%
# an.getMostPopularHashtags(df, -1)

# %%
vis.plotHashtagCloud(df)
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f86c2416a58>
